# %% [markdown]
# # 4. Estimation

# %% [markdown]
# ## Tables of Contents
#
# - [Objective](#section0)
# - [Tayor variance approximation](#section1)
# - [Replicate-based variance estimation](#section2)
#     - [Bootstrap](#section21)
#     - [BRR](#section22)
#     - [Jackknife](#section23)

# %%
import numpy as np
import pandas as pd

import samplics 
from samplics.estimation import TaylorEstimator, ReplicateEstimator

# %% [markdown]
# ## Objective <a name="section0"></a>

# %% [markdown]
# The objective of this tutorial is illustrate the use of the *samplics* estimation APIs. There are two main classes: *TaylorEstimator* and *ReplicateEstimator*. The former class uses linearization methods to estimate variance of population parameters while the latter uses replicate-based methods (bootstrap, brr/fay, and jackknife) to estimate the variance.

# %% [markdown]
# ## Taylor approximation <a name="section1"></a>

# %%
nhanes2f = pd.read_csv("nhanes2f.csv")

#nhanes2f[["psuid", "stratid", "finalwgt", "zinc"]]
nhanes2f.describe()
# Out:
#               sampl       stratid         psuid        region          smsa  \
# count  10337.000000  10337.000000  10337.000000  10337.000000  10337.000000
# mean   33615.226275     16.659863      1.482151      2.582084      2.656187
# std    18412.794868      9.499389      0.499706      1.074643      1.282325
# min     1400.000000      1.000000      1.000000      1.000000      1.000000
# 25%    16760.000000      8.000000      1.000000      2.000000      1.000000
# 50%    34678.000000     16.000000      1.000000      3.000000      2.000000
# 75%    49434.000000     25.000000      2.000000      4.000000      4.000000
# max    64709.000000     32.000000      2.000000      4.000000      4.000000
#
#            location       houssiz           sex          race           age  \
# count  10337.000000  10337.000000  10337.000000  10337.000000  10337.000000
# mean      33.055142      2.944858      1.525104      1.143755     47.563703
# std       18.413021      1.695827      0.499394      0.402245     17.216777
# min        1.000000      1.000000      1.000000      1.000000     20.000000
# 25%       16.000000      2.000000      1.000000      1.000000     31.000000
# 50%       34.000000      2.000000      2.000000      1.000000     49.000000
# 75%       49.000000      4.000000      2.000000      1.000000     63.000000
# max       64.000000     14.000000      2.000000      3.000000     74.000000
#
#        ...       region4         smsa1         smsa2         smsa3  \
# count  ...  10337.000000  10337.000000  10337.000000  10337.000000
# mean   ...      0.253942      0.254136      0.290703      0.455161
# std    ...      0.435286      0.435395      0.454109      0.498010
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.000000      0.000000      0.000000      0.000000
# 50%    ...      0.000000      0.000000      0.000000      0.000000
# 75%    ...      1.000000      1.000000      1.000000      1.000000
# max    ...      1.000000      1.000000      1.000000      1.000000
#
#               rural      loglead        highbp        agegrp     highlead  \
# count  10337.000000  4942.000000  10337.000000  10337.000000  4942.000000
# mean       0.367321     2.577727      0.422947      3.356680     0.059288
# std        0.482098     0.411602      0.494051      1.735954     0.236186
# min        0.000000     0.693147      0.000000      1.000000     0.000000
# 25%        0.000000     2.302585      0.000000      2.000000     0.000000
# 50%        0.000000     2.564949      0.000000      3.000000     0.000000
# 75%        1.000000     2.833213      1.000000      5.000000     0.000000
# max        1.000000     4.382027      1.000000      6.000000     1.000000
#
#                age2
# count  10337.000000
# mean    2558.694592
# std     1616.744628
# min      400.000000
# 25%      961.000000
# 50%     2401.000000
# 75%     3969.000000
# max     5476.000000
#
# [8 rows x 58 columns]

# %% [markdown]
# We calculate the survey mean of the level of zinc using Stata and we get the following
# ![](zinc_mean_stata_str.png)

# %% [markdown]
# Using *samplics*, the same estimate can be obtained using the snippet of code below.

# %%
zinc_mean_str = TaylorEstimator("mean").estimate(
    y=nhanes2f["zinc"], 
    samp_weight=nhanes2f["finalwgt"], 
    stratum=nhanes2f["stratid"], 
    psu=nhanes2f["psuid"], 
    exclude_nan=True
)

print(zinc_mean_str)
# Out:
# SAMPLICS - Estimation of Mean
#
# Number of strata: 31
# Number of psus: 62
# Degree of freedom: 31
#
#   DOMAINS       MEAN        SE        LCI        UCI        CV
# 0     NaN  87.182067  0.494483  86.173563  88.190571  0.005672

# %% [markdown]
# <br> Let's remove the stratum parameter then we get the following with stata
# ![](zinc_mean_stata_nostr.png)

# %% [markdown]
# with samplics, we get ...

# %%
zinc_mean_nostr = TaylorEstimator("mean").estimate(
    y=nhanes2f["zinc"], 
    samp_weight=nhanes2f["finalwgt"], 
    psu=nhanes2f["psuid"], 
    exclude_nan=True
)

print(zinc_mean_nostr)
# Out:
# SAMPLICS - Estimation of Mean
#
# Number of strata: 1
# Number of psus: 2
# Degree of freedom: 1
#
#   DOMAINS       MEAN        SE        LCI        UCI        CV
# 0     NaN  87.182067  0.742622  77.746158  96.617976  0.008518

# %% [markdown]
# <br> The other parameters currently implemented in *TaylorEstimator* are TOTAL, PROPORTION and RATIO. TOTAL and PROPORTION have the same function call as the MEAN parameter. For the RATIO parameter, it is necessary to provide the parameter *x*.
#
# ![](ratio_highbp_highlead.png)

# %%
ratio_bp_lead = TaylorEstimator("ratio").estimate(
    y=nhanes2f["highbp"], 
    samp_weight=nhanes2f["finalwgt"], 
    x=nhanes2f["highlead"],
    stratum=nhanes2f["stratid"], 
    psu=nhanes2f["psuid"], 
    exclude_nan=True
)

print(ratio_bp_lead)
# Out:
# SAMPLICS - Estimation of Ratio
#
# Number of strata: 31
# Number of psus: 62
# Degree of freedom: 31
#
#   DOMAINS    RATIO        SE      LCI       UCI        CV
# 0     NaN  5.93255  0.553058  4.80458  7.060519  0.093224

# %% [markdown]
# ## Replicate-based variance estimation <a name="section2"></a>

# %% [markdown]
# ### Bootstrap  <a name="section21"></a>

# %%
nmihs_bs = pd.read_csv("nmihs_bs.csv")

nmihs_bs.describe()
# Out:
#               idnum       finwgt        scale       wgtstr          fsr  \
# count  9.953000e+03  9953.000000  9953.000000  9953.000000  9953.000000
# mean   1.249782e+07   391.733348     1.000000  1412.713453     1.066010
# std    1.468522e+06   382.161305     0.975565   166.653606     0.248312
# min    1.010002e+07    18.406610     0.046990  1111.000000     1.000000
# 25%    1.110273e+07   149.956650     0.382800  1313.000000     1.000000
# 50%    1.240030e+07   167.160800     0.426720  1324.000000     1.000000
# 75%    1.370347e+07   882.657940     2.253210  1612.000000     1.000000
# max    1.520015e+07  1228.653470     3.136450  1624.000000     2.000000
#
#            marital          age         race       highbp     vagbleed  ...  \
# count  9953.000000  9953.000000  9953.000000  9953.000000  9953.000000  ...
# mean      0.589671    25.611574     0.525068     0.059781     0.056465  ...
# std       0.491918     5.784969     0.499396     0.237093     0.230830  ...
# min       0.000000    15.000000     0.000000     0.000000     0.000000  ...
# 25%       0.000000    21.000000     0.000000     0.000000     0.000000  ...
# 50%       1.000000    25.000000     1.000000     0.000000     0.000000  ...
# 75%       1.000000    30.000000     1.000000     0.000000     0.000000  ...
# max       1.000000    46.000000     1.000000     1.000000     1.000000  ...
#
#            bsrw991     bsrw992      bsrw993      bsrw994      bsrw995  \
# count  9953.000000  9953.00000  9953.000000  9953.000000  9953.000000
# mean    391.181948   391.43303   391.796894   391.703743   391.241160
# std     665.617353   661.07383   666.929639   657.896328   664.270824
# min       0.000000     0.00000     0.000000     0.000000     0.000000
# 25%       0.000000     0.00000     0.000000     0.000000     0.000000
# 50%     143.480290   149.59361   149.998520   149.998520   149.593610
# 75%     422.964510   449.99557   422.964510   439.504430   422.964510
# max    5769.781700  7374.15330  6145.127900  5491.954100  5123.111800
#
#            bsrw996      bsrw997      bsrw998      bsrw999     bsrw1000
# count  9953.000000  9953.000000  9953.000000  9953.000000  9953.000000
# mean    391.591024   392.410848   390.743198   391.172844   391.374216
# std     660.660033   674.418284   657.544689   666.867503   658.914238
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%     149.998520   149.593610   149.998520   149.593610   149.998520
# 75%     449.995570   402.811830   422.964510   422.964510   431.914610
# max    5769.781700  5814.420400  5123.111800  5568.022900  6145.127900
#
# [8 rows x 1022 columns]

# %% [markdown]
# Let's estimate the average birth weight using the bootstrap weights. From Stata, we get
#
# ![](mean_birthwgt_bs.png)

# %% [markdown]
# Using *samplics*, we obtain ...

# %%
#rep_wgt_boot = nmihsboot.loc[:, "bsrw1":"bsrw1000"]

birthwgt = ReplicateEstimator("bootstrap", "mean").estimate(
    y=nmihs_bs["birthwgt"], 
    samp_weight=nmihs_bs["finwgt"], 
    rep_weights=nmihs_bs.loc[:, "bsrw1":"bsrw1000"],
    exclude_nan = True
)

print(birthwgt)
# Out:
# SAMPLICS - Estimation of Mean
#
# Number of strata: None
# Number of psus: None
# Degree of freedom: 999
#
#   DOMAINS         MEAN        SE          LCI          UCI        CV
# 0     NaN  3355.452419  6.520638  3342.656702  3368.248137  0.001943

# %% [markdown]
# ### BRR  <a name="section22"></a>

# %%
nhanes2brr = pd.read_csv("nhanes2brr.csv")

nhanes2brr.describe()
# Out:
#               sampl        region          smsa      location       houssiz  \
# count  10351.000000  10351.000000  10351.000000  10351.000000  10351.000000
# mean   33625.572795      2.580910      2.655975     33.065501      2.943774
# std    18412.277368      1.075327      1.282432     18.412539      1.695156
# min     1400.000000      1.000000      1.000000      1.000000      1.000000
# 25%    17402.500000      2.000000      1.000000     17.000000      2.000000
# 50%    34678.000000      3.000000      2.000000     34.000000      2.000000
# 75%    49435.500000      4.000000      4.000000     49.000000      4.000000
# max    64709.000000      4.000000      4.000000     64.000000     14.000000
#
#                 sex          race           age        height        weight  \
# count  10351.000000  10351.000000  10351.000000  10351.000000  10351.000000
# mean       1.525167      1.143561     47.579654    167.650876     71.897521
# std        0.499390      0.402008     17.214829      9.655916     15.356417
# min        1.000000      1.000000     20.000000    135.500000     30.840000
# 25%        1.000000      1.000000     31.000000    160.500000     60.669998
# 50%        2.000000      1.000000     49.000000    167.297000     70.419998
# 75%        2.000000      1.000000     63.000000    174.598010     81.190002
# max        2.000000      3.000000     74.000000    200.000000    175.880000
#
#        ...         brr_23         brr_24         brr_25         brr_26  \
# count  ...   10351.000000   10351.000000   10351.000000   10351.000000
# mean   ...   11406.227031   11539.930248   11387.076031   11321.057096
# std    ...   15160.287612   15831.644617   15719.924320   15328.882339
# min    ...       0.000000       0.000000       0.000000       0.000000
# 25%    ...       0.000000       0.000000       0.000000       0.000000
# 50%    ...    5962.000000       0.000000       0.000000    4678.000000
# 75%    ...   19094.000000   19818.000000   18024.000000   18235.000000
# max    ...  116348.000000  159268.000000  159268.000000  116348.000000
#
#              brr_27         brr_28         brr_29         brr_30  \
# count   10351.00000   10351.000000   10351.000000   10351.000000
# mean    11384.75954   11162.040383   11338.245194   11381.763888
# std     15457.87036   14878.705816   14902.358162   15411.507507
# min         0.00000       0.000000       0.000000       0.000000
# 25%         0.00000       0.000000       0.000000       0.000000
# 50%      4440.00000    4158.000000    5722.000000    5534.000000
# 75%     19106.00000   19038.000000   18878.000000   18786.000000
# max    159268.00000  123068.000000  116348.000000  159268.000000
#
#               brr_31         brr_32
# count   10351.000000   10351.000000
# mean    11446.294851   11941.538402
# std     15268.155884   15674.048108
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%      5094.000000    6202.000000
# 75%     19148.000000   20070.000000
# max    123068.000000  159268.000000
#
# [8 rows x 87 columns]

# %% [markdown]
# Let's estimate the ratio of weight over height using the brr weights. From Stata, we get
#
# ![](ratio_weight_height_brr.png)

# %%
brr = ReplicateEstimator("brr", "ratio")

ratio_wgt_hgt = brr.estimate(
    y=nhanes2brr["weight"], 
    samp_weight=nhanes2brr["finalwgt"], 
    x=nhanes2brr["height"],
    rep_weights=nhanes2brr.loc[:, "brr_1":"brr_32"],
    exclude_nan = True
)

print(ratio_wgt_hgt)
# Out:
# SAMPLICS - Estimation of Ratio
#
# Number of strata: None
# Number of psus: None
# Degree of freedom: 16.0
#
#   DOMAINS     RATIO       SE       LCI       UCI        CV
# 0     NaN  0.426812  0.00089  0.424924  0.428699  0.002086

# %% [markdown]
# ### Jackknife  <a name="section23"></a>

# %%
nhanes2jknife = pd.read_csv("nhanes2jknife.csv")

nhanes2jknife.describe()
# Out:
#               sampl        region          smsa      location       houssiz  \
# count  10351.000000  10351.000000  10351.000000  10351.000000  10351.000000
# mean   33625.572795      2.580910      2.655975     33.065501      2.943774
# std    18412.277368      1.075327      1.282432     18.412539      1.695156
# min     1400.000000      1.000000      1.000000      1.000000      1.000000
# 25%    17402.500000      2.000000      1.000000     17.000000      2.000000
# 50%    34678.000000      3.000000      2.000000     34.000000      2.000000
# 75%    49435.500000      4.000000      4.000000     49.000000      4.000000
# max    64709.000000      4.000000      4.000000     64.000000     14.000000
#
#                 sex          race           age        height        weight  \
# count  10351.000000  10351.000000  10351.000000  10351.000000  10351.000000
# mean       1.525167      1.143561     47.579654    167.650876     71.897521
# std        0.499390      0.402008     17.214829      9.655916     15.356417
# min        1.000000      1.000000     20.000000    135.500000     30.840000
# 25%        1.000000      1.000000     31.000000    160.500000     60.669998
# 50%        2.000000      1.000000     49.000000    167.297000     70.419998
# 75%        2.000000      1.000000     63.000000    174.598010     81.190002
# max        2.000000      3.000000     74.000000    200.000000    175.880000
#
#        ...        jkw_53         jkw_54        jkw_55        jkw_56  \
# count  ...  10351.000000   10351.000000  10351.000000  10351.000000
# mean   ...  11275.300454   11361.645348  11236.757318  11400.188484
# std    ...   7625.499536    8339.543004   7514.537230   7561.024713
# min    ...      0.000000       0.000000      0.000000      0.000000
# 25%    ...   6107.000000    6063.500000   5986.500000   6279.000000
# 50%    ...   9206.000000    9172.000000   9333.000000   9333.000000
# 75%    ...  14851.000000   14851.000000  15063.000000  15214.500000
# max    ...  61538.000000  159268.000000  79634.000000  79634.000000
#
#              jkw_57        jkw_58         jkw_59        jkw_60        jkw_61  \
# count  10351.000000  10351.000000   10351.000000  10351.000000  10351.000000
# mean   11322.798763  11314.147039   11324.355811  11312.589991  11296.868032
# std     7658.592794   7603.812786    7581.347187   7599.151634   7531.612336
# min        0.000000      0.000000       0.000000      0.000000      0.000000
# 25%     6145.500000   6078.000000    6109.500000   6062.500000   6006.000000
# 50%     9252.000000   9261.000000    9324.000000   9270.000000   9301.000000
# 75%    15122.000000  15104.000000   14929.500000  14923.500000  15297.500000
# max    98370.000000  79634.000000  114332.000000  79634.000000  79634.000000
#
#              jkw_62
# count  10351.000000
# mean   11340.077770
# std     7524.992924
# min        0.000000
# 25%     6078.000000
# 50%     9359.000000
# 75%    15257.500000
# max    79634.000000
#
# [8 rows x 117 columns]

# %% [markdown]
# Let's estimate the ratio of weight over height using the brr weights. From Stata, we get
#
# ![](ratio_weight_height_jknife.png)

# %% [markdown]
# In this case, stratification was used to calculate the jackknife weights. The stratum variable is not indicated in the dataset or survey design description. However, it says that the number of strata is 31 and the number of replicates is 62. Hence, the jackknife replicate coefficient is $(n_h - 1) / n_h = (2-1) / 2 = 0.5$. Now we can call *replicate()* and specify *rep_coefs = 0.5*.

# %%
jackknife = ReplicateEstimator("jackknife", "ratio")

ratio_wgt_hgt2 = jackknife.estimate(
    y=nhanes2jknife["weight"], 
    samp_weight=nhanes2jknife["finalwgt"], 
    x=nhanes2jknife["height"],
    rep_weights=nhanes2jknife.loc[:, "jkw_1":"jkw_62"],
    rep_coefs = 0.5,
    exclude_nan = True
)

print(ratio_wgt_hgt2)
# Out:
# SAMPLICS - Estimation of Ratio
#
# Number of strata: None
# Number of psus: None
# Degree of freedom: 61
#
#   DOMAINS     RATIO        SE       LCI       UCI        CV
# 0     NaN  0.426812  0.000889  0.425035  0.428589  0.002082
